# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# import dependencies
import random
import pandas as pd 
import time 
import seaborn as sns 
import matplotlib.pyplot as plt 
import numpy as np
from datetime import datetime
import openweathermapy as owm

# %%
import csv
from citipy import citipy

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %%
from api_keys import api_key
settings = {"units": "imperial", "appid": api_key}


# Initialize data frame to store data from API calls
WeatherPy_df =pd.DataFrame(columns = ["City","Cloudiness", "Country",
                                    "Date", "Max Temp", "Wind Speed", 
                                    "Lat","Lng", "Humidity"])

# %%
count = 1 # counter to count the number of calls to API
err = 0 # error count to record how many cities the API responds back with no data.
sets = 0 # counter to count the number of call sets
index = 0 # index for the data frame WeatherPy data frame
#Get current time
t0 =time.time()
print(f'Beginning Data Retrieval \n ........................')
for city in cities:
    try:
        city1 = city.replace(" ", "%20") # remove space in city name so the URL retrieved is not broken.
        print(f'Processing Record {count} of Set {sets} | {city}' )
        print(f'{owm.BASE_URL}weather?q={city1}&units=imperial&APPID={api_key}')
        city_stats = owm.get_current(city, **settings)
        WeatherPy_df.set_value(index, "City", city_stats["name"])
        WeatherPy_df.set_value(index, "Cloudiness", city_stats("clouds.all"))
        WeatherPy_df.set_value(index, "Country", city_stats("sys.country"))
        WeatherPy_df.set_value(index, "Date", city_stats("dt"))
        WeatherPy_df.set_value(index, "Max Temp", city_stats("main.temp_max"))
        WeatherPy_df.set_value(index, "Wind Speed", city_stats("wind.speed"))
        WeatherPy_df.set_value(index, "Lat", city_stats("coord.lat"))
        WeatherPy_df.set_value(index, "Lng", city_stats("coord.lon"))
        WeatherPy_df.set_value(index, "Humidity", city_stats("main.humidity"))
        index = index +1 
    except Exception as e:
        print(e)
        err= err+1
    count = count+1
    if count == 51: # loop to limit 50 API calls per minute. The OpenWeatherMap API limit is 60 calls/min
        t1=time.time()
        count = 1 
        sets = sets+1
        time.sleep(60-(t1-t0))
        t0=time.time()

print("end of stats loop")
print(f'Could not get data for {err} cities')
# Out:
# Beginning Data Retrieval
#  ........................
# Processing Record 1 of Set 0 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# C:\Users\vijay\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# C:\Users\vijay\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
# C:\Users\vijay\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   app.launch_new_instance()
# C:\Users\vijay\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\vijay\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:18: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\vijay\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:19: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\vijay\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\vijay\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:21: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\vijay\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:22: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# Processing Record 2 of Set 0 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?q=mar%20del%20plata&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 3 of Set 0 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?q=hithadhoo&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 4 of Set 0 | butaritari
# http://api.openweathermap.org/data/2.5/weather?q=butaritari&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 5 of Set 0 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?q=los%20llanos%20de%20aridane&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 6 of Set 0 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?q=belushya%20guba&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# HTTP Error 404: Not Found
# Processing Record 7 of Set 0 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?q=nikolskoye&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 8 of Set 0 | seymchan
# http://api.openweathermap.org/data/2.5/weather?q=seymchan&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 9 of Set 0 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta%20arenas&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 10 of Set 0 | lata
# http://api.openweathermap.org/data/2.5/weather?q=lata&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 11 of Set 0 | poronaysk
# http://api.openweathermap.org/data/2.5/weather?q=poronaysk&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 12 of Set 0 | wellington
# http://api.openweathermap.org/data/2.5/weather?q=wellington&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 13 of Set 0 | busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 14 of Set 0 | hilo
# http://api.openweathermap.org/data/2.5/weather?q=hilo&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 15 of Set 0 | halifax
# http://api.openweathermap.org/data/2.5/weather?q=halifax&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 16 of Set 0 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?q=taolanaro&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# HTTP Error 404: Not Found
# Processing Record 17 of Set 0 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?q=sao%20joao%20da%20barra&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 18 of Set 0 | lagoa
# http://api.openweathermap.org/data/2.5/weather?q=lagoa&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 19 of Set 0 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?q=lavrentiya&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 20 of Set 0 | grenada
# http://api.openweathermap.org/data/2.5/weather?q=grenada&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 21 of Set 0 | riyadh
# http://api.openweathermap.org/data/2.5/weather?q=riyadh&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 22 of Set 0 | khatanga
# http://api.openweathermap.org/data/2.5/weather?q=khatanga&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 23 of Set 0 | esperance
# http://api.openweathermap.org/data/2.5/weather?q=esperance&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 24 of Set 0 | vaini
# http://api.openweathermap.org/data/2.5/weather?q=vaini&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 25 of Set 0 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?q=ribeira%20grande&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 26 of Set 0 | mataura
# http://api.openweathermap.org/data/2.5/weather?q=mataura&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 27 of Set 0 | hermanus
# http://api.openweathermap.org/data/2.5/weather?q=hermanus&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 28 of Set 0 | narsaq
# http://api.openweathermap.org/data/2.5/weather?q=narsaq&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 29 of Set 0 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?q=port%20elizabeth&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 30 of Set 0 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?q=arraial%20do%20cabo&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 31 of Set 0 | avarua
# http://api.openweathermap.org/data/2.5/weather?q=avarua&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 32 of Set 0 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?q=guerrero%20negro&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 33 of Set 0 | tome-acu
# http://api.openweathermap.org/data/2.5/weather?q=tome-acu&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# HTTP Error 404: Not Found
# Processing Record 34 of Set 0 | asau
# http://api.openweathermap.org/data/2.5/weather?q=asau&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# HTTP Error 404: Not Found
# Processing Record 35 of Set 0 | barrow
# http://api.openweathermap.org/data/2.5/weather?q=barrow&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 36 of Set 0 | albany
# http://api.openweathermap.org/data/2.5/weather?q=albany&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 37 of Set 0 | el zapote
# http://api.openweathermap.org/data/2.5/weather?q=el%20zapote&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 38 of Set 0 | aba
# http://api.openweathermap.org/data/2.5/weather?q=aba&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 39 of Set 0 | killybegs
# http://api.openweathermap.org/data/2.5/weather?q=killybegs&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 40 of Set 0 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 41 of Set 0 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?q=srednekolymsk&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 42 of Set 0 | luganville
# http://api.openweathermap.org/data/2.5/weather?q=luganville&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 43 of Set 0 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?q=nizhneyansk&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# HTTP Error 404: Not Found
# Processing Record 44 of Set 0 | hailar
# http://api.openweathermap.org/data/2.5/weather?q=hailar&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 45 of Set 0 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?q=ponta%20do%20sol&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 46 of Set 0 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?q=puerto%20ayora&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 47 of Set 0 | pevek
# http://api.openweathermap.org/data/2.5/weather?q=pevek&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 48 of Set 0 | camacha
# http://api.openweathermap.org/data/2.5/weather?q=camacha&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 49 of Set 0 | calvia
# http://api.openweathermap.org/data/2.5/weather?q=calvia&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 50 of Set 0 | lasa
# http://api.openweathermap.org/data/2.5/weather?q=lasa&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 51 of Set 0 | rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 52 of Set 0 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?q=nanortalik&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 53 of Set 0 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?q=cabo%20san%20lucas&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 54 of Set 0 | shimoda
# http://api.openweathermap.org/data/2.5/weather?q=shimoda&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 55 of Set 0 | kodiak
# http://api.openweathermap.org/data/2.5/weather?q=kodiak&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 56 of Set 0 | quesnel
# http://api.openweathermap.org/data/2.5/weather?q=quesnel&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 57 of Set 0 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?q=kaitangata&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 58 of Set 0 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?q=carnarvon&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 59 of Set 0 | hobart
# http://api.openweathermap.org/data/2.5/weather?q=hobart&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 60 of Set 0 | tavda
# http://api.openweathermap.org/data/2.5/weather?q=tavda&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 61 of Set 0 | winslow
# http://api.openweathermap.org/data/2.5/weather?q=winslow&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 62 of Set 0 | tura
# http://api.openweathermap.org/data/2.5/weather?q=tura&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 63 of Set 0 | lishui
# http://api.openweathermap.org/data/2.5/weather?q=lishui&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 64 of Set 0 | karaul
# http://api.openweathermap.org/data/2.5/weather?q=karaul&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# HTTP Error 404: Not Found
# Processing Record 65 of Set 0 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?q=bandarbeyla&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 66 of Set 0 | gigmoto
# http://api.openweathermap.org/data/2.5/weather?q=gigmoto&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 67 of Set 0 | solnechnyy
# http://api.openweathermap.org/data/2.5/weather?q=solnechnyy&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 68 of Set 0 | porto walter
# http://api.openweathermap.org/data/2.5/weather?q=porto%20walter&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 69 of Set 0 | fomboni
# http://api.openweathermap.org/data/2.5/weather?q=fomboni&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 70 of Set 0 | villa carlos paz
# http://api.openweathermap.org/data/2.5/weather?q=villa%20carlos%20paz&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 71 of Set 0 | batemans bay
# http://api.openweathermap.org/data/2.5/weather?q=batemans%20bay&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 72 of Set 0 | wilkie
# http://api.openweathermap.org/data/2.5/weather?q=wilkie&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 73 of Set 0 | dikson
# http://api.openweathermap.org/data/2.5/weather?q=dikson&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 74 of Set 0 | tucurui
# http://api.openweathermap.org/data/2.5/weather?q=tucurui&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 75 of Set 0 | jamestown
# http://api.openweathermap.org/data/2.5/weather?q=jamestown&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 76 of Set 0 | east london
# http://api.openweathermap.org/data/2.5/weather?q=east%20london&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 77 of Set 0 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?q=mahebourg&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 78 of Set 0 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?q=udachnyy&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 79 of Set 0 | atuona
# http://api.openweathermap.org/data/2.5/weather?q=atuona&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 80 of Set 0 | malanje
# http://api.openweathermap.org/data/2.5/weather?q=malanje&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 81 of Set 0 | cape town
# http://api.openweathermap.org/data/2.5/weather?q=cape%20town&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 82 of Set 0 | yialos
# http://api.openweathermap.org/data/2.5/weather?q=yialos&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# HTTP Error 404: Not Found
# Processing Record 83 of Set 0 | lompoc
# http://api.openweathermap.org/data/2.5/weather?q=lompoc&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 84 of Set 0 | georgetown
# http://api.openweathermap.org/data/2.5/weather?q=georgetown&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 85 of Set 0 | ust-kamchatsk
# http://api.openweathermap.org/data/2.5/weather?q=ust-kamchatsk&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# HTTP Error 404: Not Found
# Processing Record 86 of Set 0 | nguruka
# http://api.openweathermap.org/data/2.5/weather?q=nguruka&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 87 of Set 0 | airai
# http://api.openweathermap.org/data/2.5/weather?q=airai&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 88 of Set 0 | port hedland
# http://api.openweathermap.org/data/2.5/weather?q=port%20hedland&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 89 of Set 0 | hofn
# http://api.openweathermap.org/data/2.5/weather?q=hofn&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 90 of Set 0 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?q=ostrovnoy&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 91 of Set 0 | kahului
# http://api.openweathermap.org/data/2.5/weather?q=kahului&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 92 of Set 0 | senador guiomard
# http://api.openweathermap.org/data/2.5/weather?q=senador%20guiomard&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 93 of Set 0 | urengoy
# http://api.openweathermap.org/data/2.5/weather?q=urengoy&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 94 of Set 0 | magdagachi
# http://api.openweathermap.org/data/2.5/weather?q=magdagachi&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 95 of Set 0 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?q=cherskiy&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 96 of Set 0 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?q=grand%20river%20south%20east&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# HTTP Error 404: Not Found
# Processing Record 97 of Set 0 | praia
# http://api.openweathermap.org/data/2.5/weather?q=praia&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 98 of Set 0 | castro
# http://api.openweathermap.org/data/2.5/weather?q=castro&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 99 of Set 0 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?q=bengkulu&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# HTTP Error 404: Not Found
# Processing Record 100 of Set 0 | tsaratanana
# http://api.openweathermap.org/data/2.5/weather?q=tsaratanana&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 101 of Set 0 | dumka
# http://api.openweathermap.org/data/2.5/weather?q=dumka&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 102 of Set 0 | nam tha
# http://api.openweathermap.org/data/2.5/weather?q=nam%20tha&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# HTTP Error 404: Not Found
# Processing Record 103 of Set 0 | katsuura
# http://api.openweathermap.org/data/2.5/weather?q=katsuura&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 104 of Set 0 | mikkeli
# http://api.openweathermap.org/data/2.5/weather?q=mikkeli&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 105 of Set 0 | boda
# http://api.openweathermap.org/data/2.5/weather?q=boda&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 106 of Set 0 | saint-ambroise
# http://api.openweathermap.org/data/2.5/weather?q=saint-ambroise&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 107 of Set 0 | sabzevar
# http://api.openweathermap.org/data/2.5/weather?q=sabzevar&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 108 of Set 0 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?q=sentyabrskiy&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# HTTP Error 404: Not Found
# Processing Record 109 of Set 0 | kumluca
# http://api.openweathermap.org/data/2.5/weather?q=kumluca&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 110 of Set 0 | saleaula
# http://api.openweathermap.org/data/2.5/weather?q=saleaula&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# HTTP Error 404: Not Found
# Processing Record 111 of Set 0 | santa maria
# http://api.openweathermap.org/data/2.5/weather?q=santa%20maria&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 112 of Set 0 | alejandria
# http://api.openweathermap.org/data/2.5/weather?q=alejandria&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 113 of Set 0 | pembroke
# http://api.openweathermap.org/data/2.5/weather?q=pembroke&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 114 of Set 0 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?q=bathsheba&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 115 of Set 0 | finschhafen
# http://api.openweathermap.org/data/2.5/weather?q=finschhafen&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 116 of Set 0 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?q=pangnirtung&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 117 of Set 0 | bernalillo
# http://api.openweathermap.org/data/2.5/weather?q=bernalillo&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 118 of Set 0 | emerald
# http://api.openweathermap.org/data/2.5/weather?q=emerald&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 119 of Set 0 | ambon
# http://api.openweathermap.org/data/2.5/weather?q=ambon&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 120 of Set 0 | yumen
# http://api.openweathermap.org/data/2.5/weather?q=yumen&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 121 of Set 0 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?q=iqaluit&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 122 of Set 0 | borba
# http://api.openweathermap.org/data/2.5/weather?q=borba&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 123 of Set 0 | torbay
# http://api.openweathermap.org/data/2.5/weather?q=torbay&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 124 of Set 0 | port macquarie
# http://api.openweathermap.org/data/2.5/weather?q=port%20macquarie&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 125 of Set 0 | port hardy
# http://api.openweathermap.org/data/2.5/weather?q=port%20hardy&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 126 of Set 0 | aksu
# http://api.openweathermap.org/data/2.5/weather?q=aksu&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 127 of Set 0 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?q=leningradskiy&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 128 of Set 0 | bluff
# http://api.openweathermap.org/data/2.5/weather?q=bluff&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 129 of Set 0 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 130 of Set 0 | lethem
# http://api.openweathermap.org/data/2.5/weather?q=lethem&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 131 of Set 0 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?q=tasiilaq&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 132 of Set 0 | norman wells
# http://api.openweathermap.org/data/2.5/weather?q=norman%20wells&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 133 of Set 0 | malaya serdoba
# http://api.openweathermap.org/data/2.5/weather?q=malaya%20serdoba&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 134 of Set 0 | fairview
# http://api.openweathermap.org/data/2.5/weather?q=fairview&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 135 of Set 0 | zhezkazgan
# http://api.openweathermap.org/data/2.5/weather?q=zhezkazgan&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7
# Processing Record 136 of Set 0 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?q=severo-kurilsk&units=imperial&APPID=17b5773a9b9ba5bbb54b28d10c47a0a7

# %%
WeatherPy_df.count()

# %%
# save to csv file
WeatherPy_df.to_csv("WeatherPy.csv", encoding='utf-8', index=False)

# Display the city weather data frame
WeatherPy_df.head(10)

# %%
plt.figure(figsize=(10,8))
sns.set()
plt.scatter(WeatherPy_df["Lat"], WeatherPy_df["Max Temp"], color='Navy', alpha=0.5)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f'City Latitude vs Max Temperature ({datetime.now().date()})')
plt.savefig("LatVsTemp.png")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.set()
plt.scatter(WeatherPy_df["Lat"], WeatherPy_df["Humidity"], color='coral', alpha=0.5)
plt.ylim(10,120)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'City Latitude vs Humidity ({datetime.now().date()})')
plt.savefig("LatVsHumidity.png")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.set()
plt.scatter(WeatherPy_df["Lat"], WeatherPy_df["Cloudiness"], color='gold', alpha=0.5)

plt.ylim(-20,(WeatherPy_df["Cloudiness"].max()+10))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'City Latitude vs Cloudiness ({datetime.now().date()})')
plt.savefig("LatVsCloudiness.png")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.set()
plt.scatter(WeatherPy_df["Lat"], WeatherPy_df["Wind Speed"], color='teal', alpha=0.5)

plt.ylim((WeatherPy_df["Wind Speed"].min()-5),(WeatherPy_df["Wind Speed"].max()+5))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'City Latitude vs Wind Speed ({datetime.now().date()})')
plt.savefig("LatVsWind.png")
plt.show()
